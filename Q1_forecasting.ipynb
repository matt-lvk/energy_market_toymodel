# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)


import numpy as np
import data_utils as du
import plotters
import pandas as pd
import matplotlib.pyplot as plt
from darts import TimeSeries
from darts.utils.statistics import (
    check_seasonality, plot_acf, plot_pacf, remove_seasonality,remove_trend,
    stationarity_test_adf
)   
from darts.utils.statistics import extract_trend_and_seasonality
from darts.utils.model_selection import train_test_split
import os
from meteostat import Point, Hourly
import holidays
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

# %%
day_price_df = pd.read_csv('./data/Day-ahead_Prices_60min.csv')

day_price_df[['start_time', 'end_time']] = day_price_df['MTU (CET/CEST)']\
                                                .str.split(' - ', expand=True)
day_price_df.drop(columns=['MTU (CET/CEST)', 'BZN|DE-LU', 'Currency', 'end_time']
                , inplace=True) # assumes all currency same in same region
day_price_df.rename(columns={
    'Day-ahead Price [EUR/MWh]': 'price'
}, inplace=True)

day_price_df['start_time'] = pd.to_datetime(day_price_df['start_time'], format='%d.%m.%Y %H:%M')
day_price_ts = day_price_df.set_index('start_time') 

day_price_ts.plot()
# Out:
# <Axes: xlabel='start_time'>

# %%
day_price_df[day_price_df['price'].isna()]

missing_row = du.show_nrows_around_target(day_price_df, 'price', 5)
# Out:
# NaN at index 2042:
#        price          start_time
# 2032  199.95 2022-03-26 16:00:00
# 2033  232.42 2022-03-26 17:00:00
# 2034  262.50 2022-03-26 18:00:00
# 2035  292.24 2022-03-26 19:00:00
# 2036  270.07 2022-03-26 20:00:00
# 2037  244.98 2022-03-26 21:00:00
# 2038  244.94 2022-03-26 22:00:00
# 2039  237.75 2022-03-26 23:00:00
# 2040  235.00 2022-03-27 00:00:00
# 2041  221.93 2022-03-27 01:00:00
# 2042     NaN 2022-03-27 02:00:00
# 2043  214.02 2022-03-27 03:00:00
# 2044  212.00 2022-03-27 04:00:00
# 2045  211.09 2022-03-27 05:00:00
# 2046  210.31 2022-03-27 06:00:00
# 2047  214.03 2022-03-27 07:00:00
# 2048  214.08 2022-03-27 08:00:00
# 2049  214.07 2022-03-27 09:00:00
# 2050  205.02 2022-03-27 10:00:00
# 2051  194.40 2022-03-27 11:00:00
# 2052  161.50 2022-03-27 12:00:00
# ----------------------------------------

# %%
day_price_ts['price_interpolated'] = day_price_ts['price'].interpolate(method='time')

# Analysis
start_date = datetime(2022, 3, 26, 12)
end_date = datetime(2022, 3, 27, 12)
filtered_data = day_price_ts[['price', 'price_interpolated']].loc[
    (day_price_ts.index >= start_date) & (day_price_ts.index < end_date)
]
plt.figure(figsize=(12, 6))
plt.plot(filtered_data.index, filtered_data['price'], 'b-o', label='Original Price', markersize=4)
plt.plot(filtered_data.index, filtered_data['price_interpolated'], 'r-', label='Interpolated Price')
plt.title('Original vs Interpolated Price')
plt.xlabel('Time')
plt.ylabel('Price')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)

vertical_line_time = datetime(2022, 3, 27, 2)  # Time for the vertical line
plt.axvline(x=vertical_line_time, color='green', linestyle='--', label='02:00')

plt.gcf().autofmt_xdate()
plt.tight_layout()
plt.show();

# %%
# zero_price = du.show_nrows_around_target(day_price_df, 'price', 5, 0.0)

# %%
day_price_ts.loc[(day_price_ts.index >= datetime(2022,5,20)) & (day_price_ts.index < datetime(2022,5,31))].plot()
# Out:
# <Axes: xlabel='start_time'>

# %%
day_price_ts['price'] = day_price_ts['price_interpolated']
day_price_ts = day_price_ts.drop(columns=['price_interpolated'])

# %%
day_price_ts = du.add_date_features(day_price_ts)

# %%
sns.pairplot(day_price_ts,
            hue='hour',
            x_vars=['dayofweek','weekofyear', 'is_weekend', 'month'],
            y_vars='price',
            height=5,
            plot_kws={'alpha':0.15, 'linewidth':0}
            )
plt.suptitle('Day-ahead Price [EUR/MWh]', fontsize=16)
plt.show()

# %%
plotters.plot_violin_ts(day_price_ts, 'dayofweek', 'price', 'Day-ahead Price [EUR/MWh] per day of week')

# %%
plotters.plot_violin_ts(day_price_ts, 'month', 'price', 'Day-ahead Price [EUR/MWh] per month of year')

# %%
plotters.plot_violin_ts(day_price_ts, 'weekofyear', 'price', 'Day-ahead Price [EUR/MWh] per month of year', False)

# %% [markdown]
# ### Add temperature

# %%
locations = {
    'LU': (49.815273, 6.129583),  # Luxembourg City coordinates
    'DE': (52.520008, 13.404954)  # Berlin coordinates (as an example for Germany)
}

weather_data = du.add_locations_weather(day_price_ts, locations)

# %%
merged_data = day_price_ts.merge(weather_data[['temp', 'tsun']], left_index=True, right_index=True, how='left')

# %%
import yfinance as yf

vix_close = yf.download('^VIX', start=merged_data.index.min(), end=merged_data.index.max())['Open']
dax_close = yf.download('^GDAXI', start=merged_data.index.min(), end=merged_data.index.max())['Open']
eur_usd_close = yf.download("EURUSD=X", start=merged_data.index.min(), end=merged_data.index.max())['Open']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
eur_usd_close.columns
# Out:
# Index(['EURUSD=X'], dtype='object', name='Ticker')

# %%
merged_data['price_ma_3d'] = merged_data['price'].rolling(window=3).mean()

merged_data['date'] = merged_data.index.date
vix_close['date'] = vix_close.index.date
dax_close['date'] = dax_close.index.date
eur_usd_close['date'] = eur_usd_close.index.date

merged_data = merged_data.merge(vix_close[['date', '^VIX']], 
                                 on='date', 
                                 how='left')

merged_data = merged_data.merge(dax_close[['date', '^GDAXI']], 
                                 on='date', 
                                 how='left')

merged_data = merged_data.merge(eur_usd_close[['date', 'EURUSD=X']], 
                                 on='date', 
                                 how='left')

merged_data.set_index(merged_data.index, inplace=True)
merged_data = merged_data.drop('date', axis=1).rename(columns={'^VIX': 'VIX',
                                                               '^GDAXI': 'DAX',
                                                               'EURUSD=X': 'EURUSD'})

# %%
merged_data.set_index('datetime', inplace=True)

# %%
plotters.plot_compare_two_col(merged_data, 'price', 'VIX', 'Day-ahead Price [EUR/MWh] vs VIX')

# %%
plotters.plot_compare_two_col(merged_data, 'price', 'DAX', 'Day-ahead Price [EUR/MWh] vs DAX')

# %%
df_load = pd.read_csv('./data/Forecasted_consumption_202201010000_202207010000_Hour.csv',
                        delimiter=';', parse_dates=['Start date', 'End date'])

df_load = df_load.drop(columns=['End date'])
df_load = df_load.rename(columns={'grid load [MWh] Calculated resolutions': 'grid_load',
                                    'Residual load [MWh] Calculated resolutions': 'residual_load',})

df_load['grid_load'].loc[df_load['grid_load']=='-'] = np.nan
df_load['grid_load'] = df_load['grid_load'].str.replace(',', '').astype(float)

df_load['residual_load'].loc[df_load['residual_load']=='-'] = np.nan
df_load['residual_load'] = df_load['residual_load'].str.replace(',', '').astype(float)

df_load = df_load.set_index('Start date')
# Out:
# /var/folders/bj/vqft4btx31x4b208qdl7q1nm0000gn/T/ipykernel_47355/4075160306.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#
# /var/folders/bj/vqft4btx31x4b208qdl7q1nm0000gn/T/ipykernel_47355/4075160306.py:8: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/bj/vqft4btx31x4b208qdl7q1nm0000gn/T/ipykernel_47355/4075160306.py:11: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_DH_generation = pd.read_csv('./data/Forecasted_generation_Day-Ahead_202201010000_202207010000_Hour.csv',
                        delimiter=';', parse_dates=['Start date', 'End date'])

df_DH_generation = df_DH_generation.set_index('Start date')
df_DH_generation= df_DH_generation[['Total [MWh] Original resolutions']]
df_DH_generation = df_DH_generation.rename(columns={'Total [MWh] Original resolutions': 'total_DH_generation'})
df_DH_generation['total_DH_generation'] = df_DH_generation['total_DH_generation']\
                                            .str.replace(',', '').astype(float)
# Out:
# /var/folders/bj/vqft4btx31x4b208qdl7q1nm0000gn/T/ipykernel_47355/55072728.py:1: UserWarning:
#
# Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.

# %%
merged_data = merged_data.join(df_load, how='left')
merged_data = merged_data.join(df_DH_generation, how='left')

merged_data['energy_balance'] = merged_data['total_DH_generation'] - merged_data['grid_load']

# %%
merged_data
# Out:
#                       price  is_weekend  hour  dayofweek  quarter  year  \
# datetime
# 2022-01-01 00:00:00   50.05        True     0          5        1  2022
# 2022-01-01 01:00:00   41.33        True     1          5        1  2022
# 2022-01-01 02:00:00   43.22        True     2          5        1  2022
# 2022-01-01 03:00:00   45.46        True     3          5        1  2022
# 2022-01-01 04:00:00   37.67        True     4          5        1  2022
# ...                     ...         ...   ...        ...      ...   ...
# 2022-06-30 19:00:00  479.00       False    19          3        2  2022
# 2022-06-30 20:00:00  450.00       False    20          3        2  2022
# 2022-06-30 21:00:00  394.21       False    21          3        2  2022
# 2022-06-30 22:00:00  355.17       False    22          3        2  2022
# 2022-06-30 23:00:00  258.08       False    23          3        2  2022
#
#                      dayofyear  dayofmonth  month  weekofyear  ...  temp  \
# datetime                                                       ...
# 2022-01-01 00:00:00          1           1      1          52  ...  11.9
# 2022-01-01 01:00:00          1           1      1          52  ...  11.9
# 2022-01-01 02:00:00          1           1      1          52  ...  11.9
# 2022-01-01 03:00:00          1           1      1          52  ...  11.9
# 2022-01-01 04:00:00          1           1      1          52  ...  11.8
# ...                        ...         ...    ...         ...  ...   ...
# 2022-06-30 19:00:00        181          30      6          26  ...  25.7
# 2022-06-30 20:00:00        181          30      6          26  ...  24.4
# 2022-06-30 21:00:00        181          30      6          26  ...  23.4
# 2022-06-30 22:00:00        181          30      6          26  ...  22.1
# 2022-06-30 23:00:00        181          30      6          26  ...  21.5
#
#                      tsun  price_ma_3d    VIX           DAX    EURUSD  \
# datetime
# 2022-01-01 00:00:00   0.0          NaN    NaN           NaN       NaN
# 2022-01-01 01:00:00   0.0          NaN    NaN           NaN       NaN
# 2022-01-01 02:00:00   0.0    44.866667    NaN           NaN       NaN
# 2022-01-01 03:00:00   0.0    43.336667    NaN           NaN       NaN
# 2022-01-01 04:00:00   0.0    42.116667    NaN           NaN       NaN
# ...                   ...          ...    ...           ...       ...
# 2022-06-30 19:00:00  49.0   420.283333  29.42  12795.219727  1.044659
# 2022-06-30 20:00:00   0.0   446.136667  29.42  12795.219727  1.044659
# 2022-06-30 21:00:00   0.0   441.070000  29.42  12795.219727  1.044659
# 2022-06-30 22:00:00   0.0   399.793333  29.42  12795.219727  1.044659
# 2022-06-30 23:00:00   0.0   335.820000  29.42  12795.219727  1.044659
#
#                      grid_load  residual_load  total_DH_generation  \
# datetime
# 2022-01-01 00:00:00   42310.25       10779.50              52473.0
# 2022-01-01 01:00:00   40419.00        9956.50              50246.0
# 2022-01-01 02:00:00   39095.75       10040.50              49656.0
# 2022-01-01 03:00:00   38066.50       10459.00              47619.0
# 2022-01-01 04:00:00   38188.25       11932.75              45778.0
# ...                        ...            ...                  ...
# 2022-06-30 19:00:00   59783.75       49921.50              56068.0
# 2022-06-30 20:00:00   57877.50       49577.75              54533.0
# 2022-06-30 21:00:00   55824.50       46520.75              53595.0
# 2022-06-30 22:00:00   53034.50       41779.50              53499.0
# 2022-06-30 23:00:00   49507.25       37119.00              49870.0
#
#                      energy_balance
# datetime
# 2022-01-01 00:00:00        10162.75
# 2022-01-01 01:00:00         9827.00
# 2022-01-01 02:00:00        10560.25
# 2022-01-01 03:00:00         9552.50
# 2022-01-01 04:00:00         7589.75
# ...                             ...
# 2022-06-30 19:00:00        -3715.75
# 2022-06-30 20:00:00        -3344.50
# 2022-06-30 21:00:00        -2229.50
# 2022-06-30 22:00:00          464.50
# 2022-06-30 23:00:00          362.75
#
# [4344 rows x 21 columns]

# %%
cov_matrix = merged_data.drop(['price'], axis=1).cov()

plt.figure(figsize=(12, 10))
sns.heatmap(cov_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Covariance Matrix Heatmap')
plt.show()

# %%
import xgboost as xgb
from xgboost import plot_importance, plot_tree

drop_col = [
            'price_ma_3d',
            'temp',
            'EURUSD',
            'quarter',
            'is_weekend',
            'is_holiday',
            ]
cleaned_merged_data = merged_data.drop(drop_col, axis=1)

print(cleaned_merged_data.dtypes)
# Out:
# price                  float64
# hour                     int32
# dayofweek                int32
# year                     int32
# dayofyear                int32
# dayofmonth               int32
# month                    int32
# weekofyear              UInt32
# tsun                   float64
# VIX                    float64
# DAX                    float64
# grid_load              float64
# residual_load          float64
# total_DH_generation    float64
# energy_balance         float64
# dtype: object

# %%
split_date = datetime(2022, 5, 1)
xgb_train, xgb_test = du.ts_train_test_split(cleaned_merged_data, split_date)

X_train, y_train = xgb_train.drop(['price'], axis=1), xgb_train['price']
X_test, y_test = xgb_test.drop(['price'], axis=1), xgb_test['price']

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_pacf

series_to_analyze = cleaned_merged_data['price'] if isinstance(xgb_train, pd.DataFrame) else xgb_train

# Create the PACF plot
fig, ax = plt.subplots(figsize=(12, 6))
plot_pacf(series_to_analyze, ax=ax, lags=40)  # You can adjust the number of lags as needed

# Customize the plot
plt.title('Partial Autocorrelation Function')
plt.xlabel('Lag')
plt.ylabel('PACF')

# Show the plot
plt.show()

# %%
X_train['mean_previous_4_hrs'] = y_train.shift(4).rolling(window='4H', min_periods=1).mean()
X_test['mean_previous_4_hrs'] = y_test.shift(4).rolling(window='4H', min_periods=1).mean()

X_train['mean_previous_3_hrs'] = y_train.shift(3).rolling(window='3H', min_periods=1).mean()
X_test['mean_previous_3_hrs'] = y_test.shift(3).rolling(window='3H', min_periods=1).mean()

X_train['mean_previous_2_hrs'] = y_train.shift(2).rolling(window='2H', min_periods=1).mean()
X_test['mean_previous_2_hrs'] = y_test.shift(2).rolling(window='2H', min_periods=1).mean()

X_train['mean_previous_1_hrs'] = y_train.shift(1)
X_test['mean_previous_1_hrs'] = y_test.shift(1)

# %%
X_train
# Out:
#                      hour  dayofweek  year  dayofyear  dayofmonth  month  \
# datetime
# 2022-01-01 00:00:00     0          5  2022          1           1      1
# 2022-01-01 01:00:00     1          5  2022          1           1      1
# 2022-01-01 02:00:00     2          5  2022          1           1      1
# 2022-01-01 03:00:00     3          5  2022          1           1      1
# 2022-01-01 04:00:00     4          5  2022          1           1      1
# ...                   ...        ...   ...        ...         ...    ...
# 2022-04-30 20:00:00    20          5  2022        120          30      4
# 2022-04-30 21:00:00    21          5  2022        120          30      4
# 2022-04-30 22:00:00    22          5  2022        120          30      4
# 2022-04-30 23:00:00    23          5  2022        120          30      4
# 2022-05-01 00:00:00     0          6  2022        121           1      5
#
#                      weekofyear  tsun  VIX  DAX  grid_load  residual_load  \
# datetime
# 2022-01-01 00:00:00          52   0.0  NaN  NaN   42310.25       10779.50
# 2022-01-01 01:00:00          52   0.0  NaN  NaN   40419.00        9956.50
# 2022-01-01 02:00:00          52   0.0  NaN  NaN   39095.75       10040.50
# 2022-01-01 03:00:00          52   0.0  NaN  NaN   38066.50       10459.00
# 2022-01-01 04:00:00          52   0.0  NaN  NaN   38188.25       11932.75
# ...                         ...   ...  ...  ...        ...            ...
# 2022-04-30 20:00:00          17   0.0  NaN  NaN   50698.75       45280.25
# 2022-04-30 21:00:00          17   0.0  NaN  NaN   49658.00       44204.75
# 2022-04-30 22:00:00          17   0.0  NaN  NaN   48195.25       42805.75
# 2022-04-30 23:00:00          17   0.0  NaN  NaN   45433.75       40367.75
# 2022-05-01 00:00:00          17   0.0  NaN  NaN   43121.00       38485.00
#
#                      total_DH_generation  energy_balance  mean_previous_4_hrs  \
# datetime
# 2022-01-01 00:00:00              52473.0        10162.75                  NaN
# 2022-01-01 01:00:00              50246.0         9827.00                  NaN
# 2022-01-01 02:00:00              49656.0        10560.25                  NaN
# 2022-01-01 03:00:00              47619.0         9552.50                  NaN
# 2022-01-01 04:00:00              45778.0         7589.75              50.0500
# ...                                  ...             ...                  ...
# 2022-04-30 20:00:00              45192.0        -5506.75             166.4075
# 2022-04-30 21:00:00              44308.0        -5350.00             171.1775
# 2022-04-30 22:00:00              42782.0        -5413.25             186.1125
# 2022-04-30 23:00:00              41338.0        -4095.75             207.9325
# 2022-05-01 00:00:00              37280.0        -5841.00             229.4300
#
#                      mean_previous_3_hrs  mean_previous_2_hrs  \
# datetime
# 2022-01-01 00:00:00                  NaN                  NaN
# 2022-01-01 01:00:00                  NaN                  NaN
# 2022-01-01 02:00:00                  NaN               50.050
# 2022-01-01 03:00:00            50.050000               45.690
# 2022-01-01 04:00:00            45.690000               42.275
# ...                                  ...                  ...
# 2022-04-30 20:00:00           172.786667              209.055
# 2022-04-30 21:00:00           194.920000              236.530
# 2022-04-30 22:00:00           221.693333              249.805
# 2022-04-30 23:00:00           241.900000              249.875
# 2022-05-01 00:00:00           248.906667              243.100
#
#                      mean_previous_1_hrs
# datetime
# 2022-01-01 00:00:00                  NaN
# 2022-01-01 01:00:00                50.05
# 2022-01-01 02:00:00                41.33
# 2022-01-01 03:00:00                43.22
# 2022-01-01 04:00:00                45.46
# ...                                  ...
# 2022-04-30 20:00:00               246.97
# 2022-04-30 21:00:00               252.64
# 2022-04-30 22:00:00               247.11
# 2022-04-30 23:00:00               239.09
# 2022-05-01 00:00:00               219.00
#
# [2881 rows x 18 columns]

# %%
reg = xgb.XGBRegressor(n_estimators=1000)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
       verbose=False)

plot_importance(reg, height=0.9)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Importance score', ylabel='Features'>

# %%
xgb_test['price_prediction'] = reg.predict(X_test)
predicted_XGBoost = pd.concat([xgb_test, xgb_train], sort=False)
plotters.plot_actual_predict(predicted_XGBoost, 'price', 'price_prediction', 'Day-ahead Price [EUR/MWh] Predicted with XGBoost')

# %%
xgb_rmse = np.sqrt(mean_squared_error(y_true=xgb_test['price'],
                   y_pred=xgb_test['price_prediction']))

xgb_mae = mean_absolute_error(y_true=xgb_test['price'],
                   y_pred=xgb_test['price_prediction'])

print(f"Root Mean Squared Error: {xgb_rmse}")
print(f"Mean Absolute Error: {xgb_mae}")
# Out:
# Root Mean Squared Error: 21.503728220942133
# Mean Absolute Error: 14.68235201697682

# %% [markdown]
# old
#
# RMSE: 72.62760400265705
#
# Mean Absolute Error: 54.146453745197284
#
# Mean Absolute Percentage Error: 628587622318244.4
#
# without balance
#
# Mean Squared Error: 42.12097329402923
#
# Mean Absolute Error: 29.980022588835464
#
# -----------
#
# Root Mean Squared Error: 40.878197492053715
#
# Mean Absolute Error: 29.071574118420916
#
# -------------
#
# Root Mean Squared Error: 22.98923363592281
#
# Mean Absolute Error: 15.776761318923102

# %%
merged_data['price'].std()
# Out:
# np.float64(90.64769720908464)

# %% [markdown]
# # <span style="color: #F8766D;">**ARIMA**</span>

# %%
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

arima_data = merged_data['price']

result = adfuller(arima_data.dropna())

# Output the test statistic and p-value
print(f'ADF Statistic: {result[0]}')
print(f'p-value: {result[1]}')

# Interpretation of results
if result[1] <= 0.05:
    print("Reject the null hypothesis. The series is likely stationary.")
else:
    print("Fail to reject the null hypothesis. The series is likely non-stationary.")

# Plot ACF and PACF to find p and q
plt.figure(figsize=(12, 6))

# ACF plot for q (Moving Average)
plt.subplot(121)
plot_acf(arima_data, lags=40, ax=plt.gca())

# PACF plot for p (AutoRegressive)
plt.subplot(122)
plot_pacf(arima_data, lags=40, ax=plt.gca())

plt.show()
# Out:
# ADF Statistic: -6.910400985725894
# p-value: 1.2165522240256648e-09
# Reject the null hypothesis. The series is likely stationary.

# %%
from statsmodels.tsa.arima.model import ARIMA

arima_train, arima_test = du.ts_train_test_split(merged_data['price'], split_date)

# # Loop over a range of p, d, q values
# best_aic = float('inf')
# best_order = None
# best_model = None

# for p in range(0, 6):  # Testing p values from 0 to 5
#     for d in range(0, 3):  # Testing d values from 0 to 2
#         for q in range(0, 6):  # Testing q values from 0 to 5
#             try:
#                 model = ARIMA(arima_train, order=(p, d, q))
#                 model_fit = model.fit()
#                 if model_fit.aic < best_aic:
#                     best_aic = model_fit.aic
#                     best_order = (p, d, q)
#                     best_model = model_fit
#             except:
#                 continue

# print("--------------------------------")
# print(f'Best ARIMA order: {best_order}')

# %%
arima_model = ARIMA(arima_train, order=(4, 1, 4))
arima_model_fit = arima_model.fit()

print(arima_model_fit.summary())
# Out:
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency h will be used.
#
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency h will be used.
#
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency h will be used.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                  price   No. Observations:                 2881
# Model:                 ARIMA(4, 1, 4)   Log Likelihood              -12642.207
# Date:                Fri, 16 May 2025   AIC                          25302.414
# Time:                        16:06:23   BIC                          25356.104
# Sample:                    01-01-2022   HQIC                         25321.767
#                          - 05-01-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.3903      0.044     53.859      0.000       2.303       2.477
# ar.L2         -2.7820      0.090    -30.889      0.000      -2.959      -2.605
# ar.L3          1.7704      0.077     23.047      0.000       1.620       1.921
# ar.L4         -0.6405      0.029    -21.732      0.000      -0.698      -0.583
# ma.L1         -2.0769      0.045    -46.014      0.000      -2.165      -1.988
# ma.L2          2.0998      0.078     26.976      0.000       1.947       2.252
# ma.L3         -1.2213      0.065    -18.851      0.000      -1.348      -1.094
# ma.L4          0.4796      0.033     14.473      0.000       0.415       0.545
# sigma2       367.3196      5.750     63.878      0.000     356.049     378.590
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              2219.03
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.95   Skew:                             0.19
# Prob(H) (two-sided):                  0.39   Kurtosis:                         7.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
forecast_steps = len(arima_test)
arima_forecast = arima_model_fit.forecast(steps=forecast_steps)

# Calculate MAE RMSE
arima_rmse = np.sqrt(mean_squared_error(arima_test, arima_forecast))
arima_mae = mean_absolute_error(arima_test, arima_forecast)

print(f"Root Mean Squared Error ARIMA on price_t: {arima_rmse}")
print(f"Mean Absolute Error ARIMA on price_t: {arima_mae}")
# Out:
# Root Mean Squared Error ARIMA on price_t: 80.60131111116841
# Mean Absolute Error ARIMA on price_t: 57.57410564208863

# %%
arima_pred_all = merged_data[['price']]
arima_forecast.name = 'price_prediction'
arima_forecast.to_frame()
arima_pred_all = arima_pred_all.join(arima_forecast)
plotters.plot_actual_predict(arima_pred_all, 'price', 'price_prediction', 'Day-ahead Price [EUR/MWh] Predicted with ARIMA(4,1,4)')

# %%
cleaned_merged_data.columns


cleaned_merged_data[['price']]
# Out:
#                       price
# datetime
# 2022-01-01 00:00:00   50.05
# 2022-01-01 01:00:00   41.33
# 2022-01-01 02:00:00   43.22
# 2022-01-01 03:00:00   45.46
# 2022-01-01 04:00:00   37.67
# ...                     ...
# 2022-06-30 19:00:00  479.00
# 2022-06-30 20:00:00  450.00
# 2022-06-30 21:00:00  394.21
# 2022-06-30 22:00:00  355.17
# 2022-06-30 23:00:00  258.08
#
# [4344 rows x 1 columns]

# %%
stationary_col = []

for col in cleaned_merged_data.columns:
    ts = TimeSeries.from_dataframe(cleaned_merged_data[[col]])

    try:
        stationarity_test_adf(ts)
        print(f"{col} is stationary")
        stationary_col.append(col)
    except:
        print(f"{col} is not stationary")
        continue
# Out:
# price is stationary
# hour is stationary
# dayofweek is stationary
# year is not stationary
# dayofyear is stationary
# dayofmonth is stationary
# month is stationary
# weekofyear is stationary
# tsun is stationary
# VIX is not stationary
# DAX is not stationary
# grid_load is not stationary
# residual_load is not stationary
# total_DH_generation is not stationary
# energy_balance is not stationary

# %%
stationary_col
# Out:
# ['price',
#  'hour',
#  'dayofweek',
#  'dayofyear',
#  'dayofmonth',
#  'month',
#  'weekofyear',
#  'tsun']

# %%
stationary_col.remove('price')

# %%
merged_data['weekofyear'] = merged_data['weekofyear'].astype('int32')
merged_data[stationary_col]
# Out:
#                      hour  dayofweek  dayofyear  dayofmonth  month  \
# datetime
# 2022-01-01 00:00:00     0          5          1           1      1
# 2022-01-01 01:00:00     1          5          1           1      1
# 2022-01-01 02:00:00     2          5          1           1      1
# 2022-01-01 03:00:00     3          5          1           1      1
# 2022-01-01 04:00:00     4          5          1           1      1
# ...                   ...        ...        ...         ...    ...
# 2022-06-30 19:00:00    19          3        181          30      6
# 2022-06-30 20:00:00    20          3        181          30      6
# 2022-06-30 21:00:00    21          3        181          30      6
# 2022-06-30 22:00:00    22          3        181          30      6
# 2022-06-30 23:00:00    23          3        181          30      6
#
#                      weekofyear  tsun
# datetime
# 2022-01-01 00:00:00          52   0.0
# 2022-01-01 01:00:00          52   0.0
# 2022-01-01 02:00:00          52   0.0
# 2022-01-01 03:00:00          52   0.0
# 2022-01-01 04:00:00          52   0.0
# ...                         ...   ...
# 2022-06-30 19:00:00          26  49.0
# 2022-06-30 20:00:00          26   0.0
# 2022-06-30 21:00:00          26   0.0
# 2022-06-30 22:00:00          26   0.0
# 2022-06-30 23:00:00          26   0.0
#
# [4344 rows x 7 columns]

# %%
stationary_col1 = merged_data.columns[~merged_data.columns.isin(['price', 'is_weekend','is_holiday'])]

# %%
merged_data[stationary_col1].dtypes
# Out:
# hour                     int32
# dayofweek                int32
# quarter                  int32
# year                     int32
# dayofyear                int32
# dayofmonth               int32
# month                    int32
# weekofyear               int32
# temp                   float64
# tsun                   float64
# price_ma_3d            float64
# VIX                    float64
# DAX                    float64
# EURUSD                 float64
# grid_load              float64
# residual_load          float64
# total_DH_generation    float64
# energy_balance         float64
# dtype: object

# %%
start_date = datetime(2022, 3, 15)

short_merged_data = merged_data[start_date:]

# %%
#ARIMAX
short_split_date = datetime(2022, 6, 15)

arimax_train, arimax_test = du.ts_train_test_split(short_merged_data, short_split_date)

arimax_model = ARIMA(
                    arimax_train['price'],
                    exog=arimax_train[stationary_col],
                    order=(4, 1, 4)
                    )
arimax_model_fit = arimax_model.fit()

forecast_steps = len(arimax_test)
arimax_forecast = arimax_model_fit.forecast(
                                            steps=forecast_steps,
                                            exog=arimax_test[stationary_col],
                                            dynamic=True
                                            )

# Calculate MAE RMSE
arimax_rmse = np.sqrt(mean_squared_error(arimax_test['price'], arimax_forecast))
arimax_mae = mean_absolute_error(arimax_test['price'], arimax_forecast)

print(f"Root Mean Squared Error ARIMAX: {arimax_rmse}")
print(f"Mean Absolute Error ARIMAX: {arimax_mae}")

arimax_pred_all = merged_data[['price']]
arimax_forecast.name = 'price_prediction'
arimax_forecast.to_frame()
arimax_pred_all = arimax_pred_all.join(arimax_forecast)
plotters.plot_actual_predict(arimax_pred_all, 'price', 'price_prediction', 'Day-ahead Price [EUR/MWh] Predicted with ARIMA(4,1,4)')
# Out:
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency h will be used.
#
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency h will be used.
#
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning:
#
# No frequency information was provided, so inferred frequency h will be used.
#
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/statsmodels/base/model.py:607: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals
# Root Mean Squared Error ARIMAX: 95.2743499538137
# Mean Absolute Error ARIMAX: 79.39941771617102

# %% [markdown]
# # <span style="color: #F8766D;">**Prophet**</span>

# %%
from prophet import Prophet

def index_to_column(df: pd.DataFrame, target_variable: str):
    data = df.copy()
    data['Datetime'] = pd.to_datetime(data.index)
    data.reset_index(drop=True, inplace=True)
    data = data.sort_values('Datetime')
    
    data = data.rename(columns={'Datetime': 'ds', target_variable: 'y'})
    return data

# %%
split_date = datetime(2022, 6, 29)

prophet_merged_data = index_to_column(merged_data, 'price')
prophet_train, prophet_test = du.ts_train_test_split(merged_data, split_date)
prophet_test = index_to_column(prophet_test, 'price')
prophet_train = index_to_column(prophet_train, 'price')

# %%
prophet_model = Prophet(interval_width=0.95)

prophet_model.fit(prophet_train)
prophet_pred = prophet_model.predict(prophet_test[['ds']]) # Keep the dataset format
# Out:
# 16:06:26 - cmdstanpy - INFO - Chain [1] start processing
# 16:06:26 - cmdstanpy - INFO - Chain [1] done processing

# %%
prophet_model.plot_components(prophet_pred)

# %%
prophet_pred_all = prophet_merged_data[['ds','y']]
prophet_pred_all = prophet_pred_all.merge(prophet_pred, on='ds', how='left')
prophet_pred_all.set_index('ds', inplace=True)


plotters.plot_actual_predict(prophet_pred_all,
                        'y',
                        'yhat',
                        'Day-ahead Price [EUR/MWh] Predicted with Prophet')

# %%
prophet_mae = round(mean_absolute_error(prophet_test['y'],
                                            prophet_pred['yhat']), 3)
prophet_rsme = round(np.sqrt(mean_squared_error(prophet_test['y'],
                                            prophet_pred['yhat'])), 3)

print(f"Root Mean Squared Error Prophet: {prophet_rsme}")
print(f"Mean Absolute Error Prophet: {prophet_mae}")
# Out:
# Root Mean Squared Error Prophet: 53.73
# Mean Absolute Error Prophet: 44.931

# %% [markdown]
# # <span style="color: #F8766D;">**ETS**</span>

# %%
from statsmodels.tsa.exponential_smoothing.ets import ETSModel

# %% [markdown]
# # <span style="color: #F8766D;">**Neural Network**</span>

# %%
import tensorflow as tf

# %%
nn_split_date = datetime(2022, 6, 1)

nn_train, nn_test = du.ts_train_test_split(cleaned_merged_data, nn_split_date)

dataset = tf.expand_dims(nn_train['price'].head(10), axis=-1)

# Generate a tf dataset with 10 elements (i.e. numbers 0 to 9)
dataset = tf.data.Dataset.from_tensor_slices(dataset)

# Window the data but only take those with the specified size
dataset = dataset.window(5, shift=1, drop_remainder=True)

# Flatten the windows by putting its elements in a single batch
dataset = dataset.flat_map(lambda window: window.batch(5))

# Create tuples with features (first four elements of the window) and labels (last element)
dataset = dataset.map(lambda window: (window[:-1], window[-1]))

for x,y in dataset:
    print("x = ", x.numpy())
    print("y = ", y.numpy())
    print()
# Out:
# x =  [[50.05]
#  [41.33]
#  [43.22]
#  [45.46]]
# y =  [37.67]
#
# x =  [[41.33]
#  [43.22]
#  [45.46]
#  [37.67]]
# y =  [39.7]
#
# x =  [[43.22]
#  [45.46]
#  [37.67]
#  [39.7 ]]
# y =  [40.59]
#
# x =  [[45.46]
#  [37.67]
#  [39.7 ]
#  [40.59]]
# y =  [43.26]
#
# x =  [[37.67]
#  [39.7 ]
#  [40.59]
#  [43.26]]
# y =  [49.66]
#
# x =  [[39.7 ]
#  [40.59]
#  [43.26]
#  [49.66]]
# y =  [70.05]
# 2025-05-16 16:06:29.782663: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
def windowing(data, window_size, shuffle_buffer, batch_size):
    dataset = tf.expand_dims(data, axis=-1)
    dataset = tf.data.Dataset.from_tensor_slices(dataset)
    dataset = dataset.window(window_size+1, shift=1, drop_remainder=True) # window size = 24 + 1 (test)
    dataset = dataset.flat_map(lambda window: window.batch(window_size+1))
    dataset = dataset.map(lambda window: (window[:-1], window[-1])) # (train, test) 
    dataset = dataset.shuffle(shuffle_buffer)
    dataset = dataset.batch(batch_size).prefetch(1)
    
    return dataset

# %%
train = windowing(nn_train['price'], 24, 72, 32)
test = windowing(nn_test['price'], 24, 72, 32)

# %%
dnn_model = tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=16, kernel_size=3,
                      strides=1, padding="causal",
                      activation="relu",
                      input_shape=[24,1]),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(16, activation='relu')),
    tf.keras.layers.Dense(16),
    tf.keras.layers.Dense(1)
])

dnn_model.summary()
# Out:
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 24, 16)         │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 32)             │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,833 (18.88 KB)
#  Trainable params: 4,833 (18.88 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
dnn_model.compile(loss='mae', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001))
dnn_model.fit(train, validation_data=test, epochs=100)
# Out:
# Epoch 1/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 166.4120 - val_loss: 42.9053
# Epoch 2/100
# 2025-05-16 16:06:31.666774: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /Users/matthewliew/projects/entrix_assessment/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning:
#
# Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 55.4260 - val_loss: 48.5368
# Epoch 3/100
#  23/113 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 45.8009
# 2025-05-16 16:06:32.395904: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 46.5686 - val_loss: 39.6217
# Epoch 4/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 41.6042 - val_loss: 36.8533
# Epoch 5/100
#  23/113 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 36.5897
# 2025-05-16 16:06:33.661424: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 40.7391 - val_loss: 44.5706
# Epoch 6/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 44.4921 - val_loss: 34.6274
# Epoch 7/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 825.6006 - val_loss: 561.0167
# Epoch 8/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 289.3430 - val_loss: 135.4928
# Epoch 9/100
#  23/113 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 108.4336
# 2025-05-16 16:06:36.245843: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 169.4742 - val_loss: 158.6318
# Epoch 10/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 110.4147 - val_loss: 61.7885
# Epoch 11/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 59.8187 - val_loss: 47.7429
# Epoch 12/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 61.1358 - val_loss: 55.0261
# Epoch 13/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 51.6325 - val_loss: 45.5659
# Epoch 14/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 50.0295 - val_loss: 55.7173
# Epoch 15/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 47.4578 - val_loss: 46.4620
# Epoch 16/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 50.1799 - val_loss: 43.7864
# Epoch 17/100
#  11/113 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 45.8750
# 2025-05-16 16:06:41.413275: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 48.0682 - val_loss: 44.3983
# Epoch 18/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 47.4908 - val_loss: 42.2188
# Epoch 19/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 48.3130 - val_loss: 39.2085
# Epoch 20/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 45.1773 - val_loss: 37.5433
# Epoch 21/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 43.2874 - val_loss: 57.8624
# Epoch 22/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 53.5826 - val_loss: 42.8311
# Epoch 23/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 56.4014 - val_loss: 44.0708
# Epoch 24/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 57.5340 - val_loss: 41.7997
# Epoch 25/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 55.5295 - val_loss: 40.0887
# Epoch 26/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 51.5123 - val_loss: 40.9753
# Epoch 27/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 50.2698 - val_loss: 42.3752
# Epoch 28/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 52.3256 - val_loss: 40.2884
# Epoch 29/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 51.1447 - val_loss: 40.1780
# Epoch 30/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 48.3363 - val_loss: 42.4420
# Epoch 31/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 53.4660 - val_loss: 55.2456
# Epoch 32/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 51.6604 - val_loss: 303.5157
# Epoch 33/100
#  21/113 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 199.8924
# 2025-05-16 16:06:51.629467: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 135.4824 - val_loss: 38.9178
# Epoch 34/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 44.5570 - val_loss: 34.1493
# Epoch 35/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 38.1876 - val_loss: 32.4454
# Epoch 36/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 27.7855 - val_loss: 25.0535
# Epoch 37/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 31.6003 - val_loss: 24.8430
# Epoch 38/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 25.0427 - val_loss: 22.1863
# Epoch 39/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 22.1206 - val_loss: 21.1028
# Epoch 40/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 20.8064 - val_loss: 20.7536
# Epoch 41/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.8239 - val_loss: 19.7995
# Epoch 42/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 19.4297 - val_loss: 21.5047
# Epoch 43/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.5759 - val_loss: 18.2327
# Epoch 44/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 18.1136 - val_loss: 17.5440
# Epoch 45/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 16.8752 - val_loss: 17.4248
# Epoch 46/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 15.8562 - val_loss: 16.8259
# Epoch 47/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 15.7218 - val_loss: 16.3554
# Epoch 48/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 15.1597 - val_loss: 16.2883
# Epoch 49/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 15.5132 - val_loss: 18.0327
# Epoch 50/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 15.3585 - val_loss: 16.8276
# Epoch 51/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 15.6255 - val_loss: 16.1404
# Epoch 52/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 16.1952 - val_loss: 15.5919
# Epoch 53/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.6838 - val_loss: 15.1821
# Epoch 54/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.4343 - val_loss: 15.5556
# Epoch 55/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.3208 - val_loss: 14.6288
# Epoch 56/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.4382 - val_loss: 15.2561
# Epoch 57/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.2455 - val_loss: 15.6137
# Epoch 58/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.3109 - val_loss: 16.3188
# Epoch 59/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.0885 - val_loss: 15.4199
# Epoch 60/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 13.8154 - val_loss: 16.0468
# Epoch 61/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.5016 - val_loss: 16.9196
# Epoch 62/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.7673 - val_loss: 16.2780
# Epoch 63/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.0096 - val_loss: 15.4303
# Epoch 64/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.8611 - val_loss: 19.0497
# Epoch 65/100
#  22/113 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.8489
# 2025-05-16 16:07:12.926843: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 14.3578 - val_loss: 14.1213
# Epoch 66/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.8232 - val_loss: 17.1119
# Epoch 67/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.8405 - val_loss: 15.5870
# Epoch 68/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.7132 - val_loss: 15.1152
# Epoch 69/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.6112 - val_loss: 15.9923
# Epoch 70/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 13.7209 - val_loss: 16.5229
# Epoch 71/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.8279 - val_loss: 14.9610
# Epoch 72/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.4649 - val_loss: 14.1377
# Epoch 73/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.9134 - val_loss: 15.2454
# Epoch 74/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 15.1783 - val_loss: 15.0450
# Epoch 75/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 13.3259 - val_loss: 14.4746
# Epoch 76/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.0871 - val_loss: 18.7354
# Epoch 77/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 13.4193 - val_loss: 13.9167
# Epoch 78/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.0030 - val_loss: 14.2138
# Epoch 79/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 12.9141 - val_loss: 16.2235
# Epoch 80/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 13.3832 - val_loss: 15.7360
# Epoch 81/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 14.0834 - val_loss: 18.0401
# Epoch 82/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 13.4678 - val_loss: 14.3858
# Epoch 83/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 15.9177 - val_loss: 25.9645
# Epoch 84/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 23.2132 - val_loss: 226.6835
# Epoch 85/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 558.1317 - val_loss: 35.9959
# Epoch 86/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 64.3307 - val_loss: 57.2045
# Epoch 87/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 95.3213 - val_loss: 121.6806
# Epoch 88/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 45.4571 - val_loss: 40.0879
# Epoch 89/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 31.2380 - val_loss: 41.2949
# Epoch 90/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 38.0518 - val_loss: 56.9514
# Epoch 91/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 25.3405 - val_loss: 31.5147
# Epoch 92/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.3249 - val_loss: 19.8744
# Epoch 93/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 24.5337 - val_loss: 56.9032
# Epoch 94/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 27.9471 - val_loss: 46.4934
# Epoch 95/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 23.5084 - val_loss: 22.1247
# Epoch 96/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 23.0376 - val_loss: 27.5211
# Epoch 97/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 20.4969 - val_loss: 47.8862
# Epoch 98/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.2592 - val_loss: 18.8856
# Epoch 99/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 21.9600 - val_loss: 18.1861
# Epoch 100/100
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 19.8581 - val_loss: 46.5127

# %%
metric = pd.DataFrame(dnn_model.history.history)
metric.plot()
# Out:
# <Axes: >

# %%
window_size = 24
forecast = []

train_length = len(nn_train)
df = cleaned_merged_data.copy()
forecast_series = []

# Use the model to predict data points per window size
for time in range(len(nn_test) - window_size):
    prediction = dnn_model.predict(time)
    forecast.append(prediction[0][0])

# Convert to a numpy array and drop single dimensional axes
results = np.array(forecast).squeeze()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[132], line 10
#       8 # Use the model to predict data points per window size
#       9 for time in range(len(nn_test) - window_size):
# ---> 10     prediction = dnn_model.predict(time)
#      11     forecast.append(prediction[0][0])
#      13 # Convert to a numpy array and drop single dimensional axes
#
# File ~/projects/entrix_assessment/.venv/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/projects/entrix_assessment/.venv/lib/python3.12/site-packages/keras/src/trainers/data_adapters/__init__.py:125, in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     117     return GeneratorDataAdapter(x)
#     118     # TODO: should we warn or not?
#     119     # warnings.warn(
#     120     #     "`shuffle=True` was passed, but will be ignored since the "
#    (...)    123     # )
#     124 else:
# --> 125     raise ValueError(f"Unrecognized data type: x={x} (of type {type(x)})")
#
# ValueError: Unrecognized data type: x=0 (of type <class 'int'>)

# %%
nn_pred_all = merged_data[['price']]

plotters.plot_actual_predict(nn_pred_all,
                        'price',
                        'pred_price',
                        'Day-ahead Price [EUR/MWh] Predicted with NN')
# Out:
# /var/folders/bj/vqft4btx31x4b208qdl7q1nm0000gn/T/ipykernel_9795/2241340601.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
merged_data
# Out:
#                       price  is_weekend  hour  dayofweek  quarter  year  \
# datetime
# 2022-01-01 00:00:00   50.05        True     0          5        1  2022
# 2022-01-01 01:00:00   41.33        True     1          5        1  2022
# 2022-01-01 02:00:00   43.22        True     2          5        1  2022
# 2022-01-01 03:00:00   45.46        True     3          5        1  2022
# 2022-01-01 04:00:00   37.67        True     4          5        1  2022
# ...                     ...         ...   ...        ...      ...   ...
# 2022-06-30 19:00:00  479.00       False    19          3        2  2022
# 2022-06-30 20:00:00  450.00       False    20          3        2  2022
# 2022-06-30 21:00:00  394.21       False    21          3        2  2022
# 2022-06-30 22:00:00  355.17       False    22          3        2  2022
# 2022-06-30 23:00:00  258.08       False    23          3        2  2022
#
#                      dayofyear  dayofmonth  month  weekofyear  ...  temp  \
# datetime                                                       ...
# 2022-01-01 00:00:00          1           1      1          52  ...  11.9
# 2022-01-01 01:00:00          1           1      1          52  ...  11.9
# 2022-01-01 02:00:00          1           1      1          52  ...  11.9
# 2022-01-01 03:00:00          1           1      1          52  ...  11.9
# 2022-01-01 04:00:00          1           1      1          52  ...  11.8
# ...                        ...         ...    ...         ...  ...   ...
# 2022-06-30 19:00:00        181          30      6          26  ...  25.7
# 2022-06-30 20:00:00        181          30      6          26  ...  24.4
# 2022-06-30 21:00:00        181          30      6          26  ...  23.4
# 2022-06-30 22:00:00        181          30      6          26  ...  22.1
# 2022-06-30 23:00:00        181          30      6          26  ...  21.5
#
#                      tsun  price_ma_3d    VIX           DAX    EURUSD  \
# datetime
# 2022-01-01 00:00:00   0.0          NaN    NaN           NaN       NaN
# 2022-01-01 01:00:00   0.0          NaN    NaN           NaN       NaN
# 2022-01-01 02:00:00   0.0    44.866667    NaN           NaN       NaN
# 2022-01-01 03:00:00   0.0    43.336667    NaN           NaN       NaN
# 2022-01-01 04:00:00   0.0    42.116667    NaN           NaN       NaN
# ...                   ...          ...    ...           ...       ...
# 2022-06-30 19:00:00  49.0   420.283333  29.42  12795.219727  1.044659
# 2022-06-30 20:00:00   0.0   446.136667  29.42  12795.219727  1.044659
# 2022-06-30 21:00:00   0.0   441.070000  29.42  12795.219727  1.044659
# 2022-06-30 22:00:00   0.0   399.793333  29.42  12795.219727  1.044659
# 2022-06-30 23:00:00   0.0   335.820000  29.42  12795.219727  1.044659
#
#                      grid_load  residual_load  total_DH_generation  \
# datetime
# 2022-01-01 00:00:00   42310.25       10779.50              52473.0
# 2022-01-01 01:00:00   40419.00        9956.50              50246.0
# 2022-01-01 02:00:00   39095.75       10040.50              49656.0
# 2022-01-01 03:00:00   38066.50       10459.00              47619.0
# 2022-01-01 04:00:00   38188.25       11932.75              45778.0
# ...                        ...            ...                  ...
# 2022-06-30 19:00:00   59783.75       49921.50              56068.0
# 2022-06-30 20:00:00   57877.50       49577.75              54533.0
# 2022-06-30 21:00:00   55824.50       46520.75              53595.0
# 2022-06-30 22:00:00   53034.50       41779.50              53499.0
# 2022-06-30 23:00:00   49507.25       37119.00              49870.0
#
#                      energy_balance
# datetime
# 2022-01-01 00:00:00        10162.75
# 2022-01-01 01:00:00         9827.00
# 2022-01-01 02:00:00        10560.25
# 2022-01-01 03:00:00         9552.50
# 2022-01-01 04:00:00         7589.75
# ...                             ...
# 2022-06-30 19:00:00        -3715.75
# 2022-06-30 20:00:00        -3344.50
# 2022-06-30 21:00:00        -2229.50
# 2022-06-30 22:00:00          464.50
# 2022-06-30 23:00:00          362.75
#
# [4344 rows x 21 columns]
